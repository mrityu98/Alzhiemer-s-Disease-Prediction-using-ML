# %%
import pickle

# %%
with open('xgb_model.pkl', 'rb') as file:
    loaded_xgb_model = pickle.load(file)

# %%
pip install xgboost h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xgboost as xgb
import h5py

# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_xgb_model)

# Save the pickled model to an HDF5 file
with h5py.File('xgboost_model.h5', 'w') as hf:
    hf.create_dataset('xgboost_model', data=repr(model_pickle))

# %%
with open('rf_model.pkl', 'rb') as file:
    loaded_rf_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_rf_model)

# Save the pickled model to an HDF5 file
with h5py.File('rf_model.h5', 'w') as hf:
    hf.create_dataset('rf_model', data=repr(model_pickle))

# %%
with open('gb_model.pkl', 'rb') as file:
    loaded_gb_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_gb_model)

# Save the pickled model to an HDF5 file
with h5py.File('gb_model.h5', 'w') as hf:
    hf.create_dataset('gb_model', data=repr(model_pickle))

# %%
with open('lg_model.pkl', 'rb') as file:
    loaded_lg_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_lg_model)

# Save the pickled model to an HDF5 file
with h5py.File('lg_model.h5', 'w') as hf:
    hf.create_dataset('lg_model', data=repr(model_pickle))

# %%
with open('svm_model.pkl', 'rb') as file:
    loaded_svm_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_svm_model)

# Save the pickled model to an HDF5 file
with h5py.File('svm_model.h5', 'w') as hf:
    hf.create_dataset('svm_model', data=repr(model_pickle))

# %%
with open('svm_model.pkl', 'rb') as file:
    loaded_svm_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_svm_model)

# Save the pickled model to an HDF5 file
with h5py.File('svm_model.h5', 'w') as hf:
    hf.create_dataset('svm_model', data=repr(model_pickle))

# %%
with open('knn_model.pkl', 'rb') as file:
    loaded_knn_model = pickle.load(file)

# %%
# Assuming you have a trained XGBoost model stored in the variable 'model'
# Train your model here

# Serialize the XGBoost model using pickle
model_pickle = pickle.dumps(loaded_knn_model)

# Save the pickled model to an HDF5 file
with h5py.File('knn_model.h5', 'w') as hf:
    hf.create_dataset('knn_model', data=repr(model_pickle))
