# %%
import numpy as np
import joblib



# Load the model

# %%
import joblib

# %%
loaded_rf = joblib.load("rf_model_final.joblib")

# %%
def predict_rf(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_rf.predict(arr_new))

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 rf_model=joblib.load('rf_model.h5')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File C:\Program Files\Python311\Lib\pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# KeyError: 72

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_rf(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)
# Out:
# Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC) LMCI
# enter the patient gender (M/F) M
# enter the FDG value  1.20209
# enter the MOCA score  24
# enter the ravlt_imm score  27
# enter the ravlt_lrn score  2
# is the patient married? (Enter for 1 if married else 0)  1
# is the patient white? (Enter for 1 if married else 0)  1
# count of apoe4 genes  0
# enter abeta conc.  874.1
# enter ptau conc.  13.45
# enter tau conc.  153.2
# enter cdrsb score  1
# enter adas11 score  11.33
# enter adas13 score  16.33
# enter the mmse score  25
# enter the ventricles volume  29502
# enter the hippocampus volume  8154
# enter the faq score  1
# enter the midtemp volume  20174
# [2]

# %%
loaded_xgb = joblib.load("xgboost_model_final.joblib")

# %%
loaded_xgb
# Out:
# XGBClassifier(alpha=7, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.3, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None, lambda=1,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None, ...)

# %%
def predict_xgboost(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_xgb.predict(arr_new))

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_xgboost(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)
# Out:
# Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC) CN
# enter the patient gender (M/F) F
# enter the FDG value  1.20209
# enter the MOCA score  24
# enter the ravlt_imm score  48
# enter the ravlt_lrn score  10
# is the patient married? (Enter for 1 if married else 0)  0
# is the patient white? (Enter for 1 if married else 0)  0
# count of apoe4 genes  0
# enter abeta conc.  1048
# enter ptau conc.  12.23
# enter tau conc.  128.2
# enter cdrsb score  0
# enter adas11 score  3
# enter adas13 score  3
# enter the mmse score  28
# enter the ventricles volume  13272
# enter the hippocampus volume  7606
# enter the faq score  0
# enter the midtemp volume  14746
# [0]

# %%
loaded_gb = joblib.load("gb_model_final.joblib")

# %%
def predict_gboost(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_gb.predict(arr_new))

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_gboost(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)
# Out:
# Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC) AD
# enter the patient gender (M/F) F
# enter the FDG value  1.20209
# enter the MOCA score  24
# enter the ravlt_imm score  35
# enter the ravlt_lrn score  4
# is the patient married? (Enter for 1 if married else 0)  01
# is the patient white? (Enter for 1 if married else 0)  1
# count of apoe4 genes  0
# enter abeta conc.  552.5
# enter ptau conc.  34.83
# enter tau conc.  314.5
# enter cdrsb score  3.5
# enter adas11 score  1.067
# enter adas13 score  18.67
# enter the mmse score  24
# enter the ventricles volume  32915
# enter the hippocampus volume  7797
# enter the faq score  9
# enter the midtemp volume  16195
# [1]

# %%
loaded_lg = joblib.load("lg_model_final.joblib")

# %%
loaded_lg
# Out:
# LogisticRegression(C=3.0, solver='newton-cg')

# %%
def predict_lg(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_lg.predict(arr_new))

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_lg(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)

# %%
loaded_svm = joblib.load("svm_model_final.joblib")

# %%
def predict_svm(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_svm.predict(arr_new))

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_svm(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)

# %%
loaded_knn = joblib.load("knn_model_final.joblib")

# %%
loaded_knn
# Out:
# KNeighborsClassifier(n_neighbors=25, weights='distance')

# %%
def predict_knn(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp):
    arr=np.zeros(23)
    if dx_bl == "AD":
        arr[16]=1
    elif dx_bl == "CN":
        arr[17]=1
    elif dx_bl == "LMCI":
        arr[18]=1
    elif dx_bl == "SMC":
        arr[19]=1

    if gender == "M":
        arr[20]=1

    arr[0]=fdg
    arr[1]=moca
    arr[2]=ravlt_imm
    arr[3]=ravlt_lrn
    arr[21]=is_marry
    arr[22]=is_white
    arr[4]=apoe_gene
    arr[5]=abeta
    arr[6]=ptau
    arr[7]=tau
    arr[8]=cdrsb
    arr[9]=adas11
    arr[10]=adas13
    arr[11]=mmse
    arr[12]=ventricles
    arr[13]=hippocampus
    arr[14]=faq
    arr[15]=midtemp


  
    arr_new=arr.reshape(1,-1)
    print(loaded_knn.predict(arr_new))

# %%
dx_bl=input("Enter the baseline diagnostic (AD/CN/EMCI/LMCI/SMC)")
gender=input("enter the patient gender (M/F)")
fdg=float(input("enter the FDG value "))
moca=int(input("enter the MOCA score "))
ravlt_imm=int(input("enter the ravlt_imm score "))
ravlt_lrn=int(input("enter the ravlt_lrn score "))
is_marry=int(input("is the patient married? (Enter for 1 if married else 0) "))
is_white=int(input("is the patient white? (Enter for 1 if married else 0) "))
apoe_gene=int(input("count of apoe4 genes "))
abeta=float(input("enter abeta conc. "))
ptau=float(input("enter ptau conc. "))
tau=float(input("enter tau conc. "))
cdrsb=float(input("enter cdrsb score "))
adas11=float(input("enter adas11 score "))
adas13=float(input("enter adas13 score "))
mmse=int(input("enter the mmse score "))
ventricles=float(input("enter the ventricles volume "))
hippocampus=float(input("enter the hippocampus volume "))
faq=int(input("enter the faq score "))
midtemp=float(input("enter the midtemp volume "))

predict_knn(dx_bl,gender,fdg,moca,ravlt_imm,ravlt_lrn,is_marry,is_white,apoe_gene,abeta,ptau,tau,cdrsb,adas11,adas13,mmse,ventricles,hippocampus,faq,midtemp)
