# %%
import pandas as pd

# %%
df_main=pd.read_csv('../Dataset/main.csv')
df_main
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX.bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
# 1         2  011_S_0002     m06    11   ADNI1    ADNI1  2006-03-06    CN
# 2         2  011_S_0002     m36    11   ADNI1    ADNI1  2008-08-27    CN
# 3         2  011_S_0002     m60    11  ADNIGO    ADNI1  2010-09-22    CN
# 4         2  011_S_0002     m66    11  ADNIGO    ADNI1  2011-03-04    CN
# ...     ...         ...     ...   ...     ...      ...         ...   ...
# 11144  5292  057_S_5292     m06    57   ADNI2    ADNI2  2014-05-08   SMC
# 11145  5294  051_S_5294      bl    51   ADNI2    ADNI2  2013-11-25   SMC
# 11146  5295  057_S_5295      bl    57   ADNI2    ADNI2  2013-12-11   SMC
# 11147  5295  057_S_5295     m03    57   ADNI2    ADNI2  2014-02-14   SMC
# 11148  5296  053_S_5296      bl    53   ADNI2    ADNI2  2013-12-18   SMC
#
#         AGE PTGENDER  ...  EcogSPOrgan.bl EcogSPDivatt.bl EcogSPTotal.bl  \
# ...

# %%
df_main.columns
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
#        'DX.bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT', 'PTRACCAT',
#        'PTMARRY', 'APOE4', 'FDG', 'PIB', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13',
#        'MMSE', 'RAVLT.immediate', 'RAVLT.learning', 'RAVLT.forgetting',
#        'RAVLT.perc.forgetting', 'FAQ', 'MOCA', 'EcogPtMem', 'EcogPtLang',
#        'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt',
#        'EcogPtTotal', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV',
#        'DX', 'EXAMDATE.bl', 'CDRSB.bl', 'ADAS11.bl', 'ADAS13.bl', 'MMSE.bl',
#        'RAVLT.immediate.bl', 'RAVLT.learning.bl', 'RAVLT.forgetting.bl',
#        'RAVLT.perc.forgetting.bl', 'FAQ.bl', 'Ventricles.bl', 'Hippocampus.bl',
# ...

# %%
df_main.dtypes
# Out:
# RID           int64
# PTID         object
# VISCODE      object
# SITE          int64
# COLPROT      object
#              ...
# AV45.bl     float64
# Years.bl    float64
# Month.bl    float64
# Month       float64
# M             int64
# Length: 89, dtype: object

# %%
df_main.describe()
# Out:
#                 RID          SITE           AGE      PTEDUCAT         APOE4  \
# count  11149.000000  11149.000000  11149.000000  11149.000000  10689.000000
# mean    2084.674500     72.672885     74.004826     15.962418      0.542801
# std     1819.238884    106.660123      6.958396      2.846152      0.656943
# min        2.000000      2.000000     48.100000      4.000000      0.000000
# 25%      558.000000     21.000000     70.000000     14.000000      0.000000
# 50%     1190.000000     41.000000     74.000000     16.000000      0.000000
# 75%     4237.000000    116.000000     79.000000     18.000000      1.000000
# max     5296.000000    941.000000     91.400000     20.000000      2.000000
#
#                FDG         PIB         AV45        CDRSB       ADAS11  ...  \
# count  3245.000000  224.000000  1427.000000  7608.000000  7642.000000  ...
# mean      6.040951    1.782857     1.194378     2.118494    11.557608  ...
# ...

# %%
df_main.isnull().sum()
# Out:
# RID            0
# PTID           0
# VISCODE        0
# SITE           0
# COLPROT        0
#             ...
# AV45.bl     6705
# Years.bl       0
# Month.bl       0
# Month          2
# M              0
# Length: 89, dtype: int64

# %%
import matplotlib.pyplot as plt
df_main['AGE'].hist(color="red")
plt.title('Distribution of AGE')
plt.xlabel('AGE')
plt.ylabel('Count of patients')
plt.show()

# %%
df_main['PTGENDER'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df_main['PTGENDER'].value_counts()
# Out:
# Male      6330
# Female    4819
# Name: PTGENDER, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(df_main['PTGENDER'].unique(),df_main['PTGENDER'].value_counts(),color="black")
plt.title('Distribution of GENDER')
plt.xlabel('GENDER')
plt.ylabel('Number of patients')
plt.show()

# %%
import matplotlib.pyplot as plt
df_main['PTEDUCAT'].hist(color="green")
plt.title('Distribution of Education Scores')
plt.xlabel('Education Score')
plt.ylabel('Count of patients')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,6))
df_main['PTRACCAT'].hist(color="pink")
plt.title('Distribution of Ethnicity')
plt.xlabel('Ethnicity')
plt.ylabel('Count of patients')
# Out:
# Text(0, 0.5, 'Count of patients')

# %%
df_main['APOE4'].isnull().sum()
# Out:
# 460

# %%
import matplotlib.pyplot as plt
df_main['MMSE'].hist(color="brown")
plt.title('Distribution of MMSE Scores')
plt.xlabel('MMSE Score')
plt.ylabel('Count of patients')
plt.show()

# %%
df_main['DX.bl'].isnull().sum()
# Out:
# 2

# %%
df_main['DX.bl'].unique()
# Out:
# array(['CN', 'AD', 'LMCI', 'EMCI', 'SMC', nan], dtype=object)

# %%
li=[]
for i in df_main['DX.bl']:
    li.append(i)
li
# Out:
# ['CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'LMCI',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'AD',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
#  'CN',
# ...

# %%
df_main_new=df_main[~df_main['DX.bl'].isnull()]
dx_bl_rid=df_main['RID'].unique()
dx_bl={}
for i in dx_bl_rid:
    for j in (df_main.index[df_main['RID']==i].tolist()):
        if df_main['DX.bl'][j] in dx_bl:
            dx_bl[df_main['DX.bl'][j]]+=1
        else:
            dx_bl[df_main['DX.bl'][j]]=1
        break

dx_bl
# Out:
# {'CN': 416, 'AD': 340, 'LMCI': 562, 'EMCI': 311, 'SMC': 106, nan: 1}

# %%
type(dx_bl.keys())
dx_bl_val=[]
for num in dx_bl.keys():
    dx_bl_val.append(str(num))
dx_bl_val
# Out:
# ['CN', 'AD', 'LMCI', 'EMCI', 'SMC', 'nan']

# %%
dx_bl_int=[]
for num in dx_bl.values():
    dx_bl_int.append(int(num))
dx_bl_int
# Out:
# [416, 340, 562, 311, 106, 1]

# %%
import matplotlib.pyplot as plt
plt.bar(dx_bl_val,dx_bl_int,color="blue")
plt.title('Distribution of stages of AD')
plt.xlabel('Stages')
plt.ylabel('Number of patients')
plt.show()

# %%
df_main['DX'].isnull().sum()
# Out:
# 3536

# %%
df_main_new2=df_main[~df_main['DX'].isnull()]
df_main_new2
# Out:
#         RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX.bl  \
# 0         2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN
# 1         2  011_S_0002     m06    11   ADNI1    ADNI1  2006-03-06    CN
# 2         2  011_S_0002     m36    11   ADNI1    ADNI1  2008-08-27    CN
# 3         2  011_S_0002     m60    11  ADNIGO    ADNI1  2010-09-22    CN
# 5         2  011_S_0002     m72    11   ADNI2    ADNI1  2011-09-19    CN
# ...     ...         ...     ...   ...     ...      ...         ...   ...
# 11143  5292  057_S_5292      bl    57   ADNI2    ADNI2  2013-11-12   SMC
# 11144  5292  057_S_5292     m06    57   ADNI2    ADNI2  2014-05-08   SMC
# 11145  5294  051_S_5294      bl    51   ADNI2    ADNI2  2013-11-25   SMC
# 11146  5295  057_S_5295      bl    57   ADNI2    ADNI2  2013-12-11   SMC
# 11148  5296  053_S_5296      bl    53   ADNI2    ADNI2  2013-12-18   SMC
#
#         AGE PTGENDER  ...  EcogSPOrgan.bl EcogSPDivatt.bl EcogSPTotal.bl  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Filter the DataFrame to include only numeric columns
df_main_trimmed = df_main_new2.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = df_main_trimmed.corr()

# Visualize the correlation matrix
plt.figure(figsize=(42,36))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()

# %%
df_main_new2['DX.bl'].unique()
# Out:
# array(['CN', 'AD', 'LMCI', 'EMCI', 'SMC', nan], dtype=object)

# %%
df_main_new2['DX'].unique()
# Out:
# array(['NL', 'NL to MCI', 'Dementia', 'MCI', 'MCI to Dementia',
#        'MCI to NL', 'Dementia to MCI', 'NL to Dementia'], dtype=object)
